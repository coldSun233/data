# %%
import pandas as pd

# %%
input_path = './userid-timestamp-artid-artname-traid-traname.tsv'
header = ['userid', 'time', 'artid', 'artname', 'music_id','music']
chunks = pd.read_csv(input_path, sep='\t', names=header, error_bad_lines=False, iterator = True, engine='python')
chunk = chunks.get_chunk(1000000)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-13-853388e0e35b> in <module>
#       2 header = ['userid', 'time', 'artid', 'artname', 'music_id','music']
#       3 chunks = pd.read_csv(input_path, sep='\t', names=header, error_bad_lines=False, iterator = True, engine='python')
# ----> 4 chunk = chunks.get_chunk(1000000)
#
# ~/.virtualenvs/jupyter_env/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1218                 raise StopIteration
#    1219             size = min(size, self.nrows - self._currow)
# -> 1220         return self.read(nrows=size)
#    1221
#    1222
#
# ~/.virtualenvs/jupyter_env/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
# ...

# %%
chunk
# Out:
#             userid                  time  \
# 0      user_000001  2009-05-04T23:08:57Z
# 1      user_000001  2009-05-04T13:54:10Z
# 2      user_000001  2009-05-04T13:52:04Z
# 3      user_000001  2009-05-04T13:42:52Z
# 4      user_000001  2009-05-04T13:42:11Z
# ...            ...                   ...
# 99995  user_000004  2008-03-20T14:08:49Z
# 99996  user_000004  2008-03-20T14:04:57Z
# 99997  user_000004  2008-03-20T13:59:30Z
# 99998  user_000004  2008-03-20T13:55:22Z
# 99999  user_000004  2008-03-20T13:50:49Z
#
#                                       artid              artname  \
# 0      f1b1cf71-bd35-4e99-8624-24a6e15f133a            Deep Dish
# 1      a7f7df4a-77d8-4f12-8acd-5c60c93f4de8                 坂本龍一
# 2      a7f7df4a-77d8-4f12-8acd-5c60c93f4de8                 坂本龍一
# 3      a7f7df4a-77d8-4f12-8acd-5c60c93f4de8                 坂本龍一
# 4      a7f7df4a-77d8-4f12-8acd-5c60c93f4de8                 坂本龍一
# ...                                     ...                  ...
# ...

# %%
df_chunk=pd.read_csv(input_path, sep='\t', names=header, error_bad_lines=False, engine='python',chunksize=1000)
res_chunk=[]
for chunk in df_chunk:
    res_chunk.append(chunk)
res_df=pd.concat(res_chunk)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-10-4d67d822f968> in <module>
#       1 df_chunk=pd.read_csv(input_path, sep='\t', names=header, error_bad_lines=False, engine='python',chunksize=1000)
#       2 res_chunk=[]
# ----> 3 for chunk in df_chunk:
#       4     res_chunk.append(chunk)
#       5 res_df=pd.concat(res_chunk)
#
# ~/.virtualenvs/jupyter_env/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1159     def __next__(self):
#    1160         try:
# -> 1161             return self.get_chunk()
#    1162         except StopIteration:
#    1163             self.close()
#
# ~/.virtualenvs/jupyter_env/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1218                 raise StopIteration
#    1219             size = min(size, self.nrows - self._currow)
# -> 1220         return self.read(nrows=size)
# ...
